# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #ETL PROJECT PYTHON +SQL#

# %%
df=pd.read_csv("orders.csv")
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
df.isnull()
# Out:
#       Order Id  Order Date  Ship Mode  Segment  Country   City  State  \
# 0        False       False      False    False    False  False  False
# 1        False       False      False    False    False  False  False
# 2        False       False      False    False    False  False  False
# 3        False       False      False    False    False  False  False
# 4        False       False      False    False    False  False  False
# ...        ...         ...        ...      ...      ...    ...    ...
# 9989     False       False      False    False    False  False  False
# 9990     False       False      False    False    False  False  False
# 9991     False       False      False    False    False  False  False
# 9992     False       False      False    False    False  False  False
# 9993     False       False      False    False    False  False  False
#
#       Postal Code  Region  Category  Sub Category  Product Id  cost price  \
# ...

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %% [markdown]
# #Here there is no value as "null", but the synonyms 'Not Available', 'unknown', is the same as null. now we need to transform and clean#

# %%
df=pd.read_csv("orders.csv",na_values=['Not Available', 'unknown'])

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
#Now all The 'Not Available', 'unknown' are treated as null now.

# %%
df.columns
# Out:
# Index(['Order Id', 'Order Date', 'Ship Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Category', 'Sub Category',
#        'Product Id', 'cost price', 'List Price', 'Quantity',
#        'Discount Percent'],
#       dtype='object')

# %% [markdown]
# #let us rename the column name by filling the gaps with underscores#

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df
# Out:
#       Order_Id  Order_Date       Ship_Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# ...

# %%
df.columns
# Out:
# Index(['Order_Id', 'Order_Date', 'Ship_Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal_Code', 'Region', 'Category', 'Sub_Category',
#        'Product_Id', 'cost_price', 'List_Price', 'Quantity',
#        'Discount_Percent'],
#       dtype='object')

# %% [markdown]
# **All The column names have been replace with underscores**

# %%
df.head()
# Out:
#    Order_Id  Order_Date       Ship_Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal_Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub_Category       Product_Id  cost_price  List_Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %% [markdown]
# #Now LETS ANALYSE THE TOTAL DISCOUNT GIVEN TO CUSTOMERS. lETS ADD AN COLUMN**#

# %%
df['Discount']=df['List_Price']*df['Discount_Percent']*.01

# %%
df
# Out:
#       Order_Id  Order_Date       Ship_Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# ...

# %% [markdown]
# #We dont have selling price here, lets find the selling price here#

# %%
df['Sales_price']=df['List_Price']-df['Discount']
df
# Out:
#       Order_Id  Order_Date       Ship_Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# ...

# %%
df['Profit']=df['Sales_price']-df['cost_price']

# %%
df
# Out:
#       Order_Id  Order_Date       Ship_Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# ...

# %%
df.dtypes
# Out:
# Order_Id              int64
# Order_Date           object
# Ship_Mode            object
# Segment              object
# Country              object
# City                 object
# State                object
# Postal_Code           int64
# Region               object
# Category             object
# Sub_Category         object
# Product_Id           object
# cost_price            int64
# List_Price            int64
# Quantity              int64
# Discount_Percent      int64
# Discount            float64
# Sales_price         float64
# Profit              float64
# dtype: object

# %%
df['Order_Date']=pd.to_datetime(df['Order_Date'],format="%Y-%m-%d")

# %%
df['Order_Date']
# Out:
# 0      2023-03-01
# 1      2023-08-15
# 2      2023-01-10
# 3      2022-06-18
# 4      2022-07-13
#           ...
# 9989   2023-02-18
# 9990   2023-03-17
# 9991   2022-08-07
# 9992   2022-11-19
# 9993   2022-07-17
# Name: Order_Date, Length: 9994, dtype: datetime64[ns]

# %%
df.columns
# Out:
# Index(['Order_Id', 'Order_Date', 'Ship_Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal_Code', 'Region', 'Category', 'Sub_Category',
#        'Product_Id', 'cost_price', 'List_Price', 'Quantity',
#        'Discount_Percent', 'Discount', 'Sales_price', 'Profit'],
#       dtype='object')

# %% [markdown]
# #lets remove unwanted data columns#

# %%
df.drop(columns=['List_Price','cost_price','Discount_Percent'],inplace=True)

# %%
df.columns
# Out:
# Index(['Order_Id', 'Order_Date', 'Ship_Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal_Code', 'Region', 'Category', 'Sub_Category',
#        'Product_Id', 'Quantity', 'Discount', 'Sales_price', 'Profit'],
#       dtype='object')

# %% [markdown]
# #All the unnecessary columns are dopped and the final columns are here#

# %% [markdown]
# #Connecting Mysql for queries#

# %%
import mysql.connector as sql

# %%
db = sql.connect(
    host="localhost",
    user="root",
    password="123456789",
    database="testdb",
    auth_plugin='mysql_native_password'
)

my_cursor = db.cursor()
print(db)

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://root:123456789@localhost/testdb')

# %%
conn=engine.connect

# %%
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df.to_sql('orders', con=engine, if_exists='replace', index=False)
# Out:
# 9994

# %% [raw]
# ##Connection Established with Sql:--##

# %%
df.to_sql('orders', con=engine, if_exists='append', index=False)
# Out:
# 9994

# %%
df.columns
# Out:
# Index(['Order_Id', 'Order_Date', 'Ship_Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal_Code', 'Region', 'Category', 'Sub_Category',
#        'Product_Id', 'Quantity', 'Discount', 'Sales_price', 'Profit'],
#       dtype='object')

# %% [markdown]
# #Lets start with Analysis!#
